# %% [markdown]
# ### Implementing Basic Data Validation with Great Expectations
# **Description**: Set up a simple data validation using Great Expectations to check the completeness of a dataset.
#
# **Steps**:
# 1. Installation
# 2. Initialize Great Expectations
# 3. Create a Data Context in Python
# 4. Create an Expectation Suite
# 5. Load Sample Data and Validate Completeness
# 6. Run Validations

# %%
# write your code from here

import pandas as pd
# Ensure great_expectations is installed: pip install great_expectations
from great_expectations.data_context import DataContext
from great_expectations.core.batch import RuntimeBatchRequest
from great_expectations.data_connector import RuntimeDataConnector
from great_expectations.validator.validator import Validator
from great_expectations.core.expectation_configuration import ExpectationConfiguration
from great_expectations.core.expectation_suite import ExpectationSuite
from great_expectations.data_context.types.base import DataContextConfig,DatasourceConfig,ExpectationSuiteConfig
from great_expectations.data_context.types.resource import DataConnectorConfig
try:
    context=DataContext()
except Exception:
    context_config=DataContextConfig(datasources={"my_in_memory_datasource":DatasourceConfig(class_name="PandasDatasource",module_name="great_expectations.datasource",data_connectors={"runtime_data_connector":DataConnectorConfig(class_name="RuntimeDataConnector",module_name="great_expectations.data_connector",batch_identifiers=["batch_id"],)})},store_backend_defaults={"module_name":"great_expectations.data_context.store","class_name":"InMemoryStoreBackend"},config_variables_file_path=None,anonymous_usage_statistics={"enabled":False},checkpoint_store_name="checkpoint_store",evaluation_parameter_store_name="evaluation_parameter_store",expectations_store_name="expectations_store",validation_operators=None,plugins_directory=None,concurrency_config=None,)
    context=DataContext(project_config=context_config)
expectation_suite_name="completeness_validation_suite"
suite=context.create_expectation_suite(expectation_suite_name,overwrite_existing=True)
data={'A':[1,2,3,None,5],'B':['x','y',None,'z','w'],'C':[True,False,True,True,False]}
df=pd.DataFrame(data)
suite.add_expectation(ExpectationConfiguration(expectation_type="expect_column_values_to_not_be_null",column="A"))
suite.add_expectation(ExpectationConfiguration(expectation_type="expect_column_values_to_not_be_null",column="B"))
suite.add_expectation(ExpectationConfiguration(expectation_type="expect_column_values_to_not_be_null",column="C"))
context.save_expectation_suite(suite,expectation_suite_name)
batch_request=RuntimeBatchRequest(datasource_name="my_in_memory_datasource",data_connector_name="runtime_data_connector",data_asset_name="my_sample_data",runtime_parameters={"batch_data":df},batch_identifiers={"batch_id":"first_batch"},)
validator=context.get_validator(batch_request=batch_request,expectation_suite_name=expectation_suite_name)
validation_result=validator.validate()
print(validation_result.to_json_dict())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 5
#       3 import pandas as pd
#       4 # Ensure great_expectations is installed: pip install great_expectations
# ----> 5 from great_expectations.data_context import DataContext
#       6 from great_expectations.core.batch import RuntimeBatchRequest
#       7 from great_expectations.data_connector import RuntimeDataConnector
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/__init__.py:11
#       7 del _get_versions
#       9 # Submodules must be imported first to avoid circular dependencies
#      10 # with data_context being the first
# ---> 11 from . import data_context  # isort:skip
#      12 from . import core
#      13 from . import exceptions
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/__init__.py:1
# ----> 1 from great_expectations.data_context.data_context import (
#       2     AbstractDataContext,
#       3     CloudDataContext,
#       4     EphemeralDataContext,
#       5     FileDataContext,
#       6     get_context,
#       7     project_manager,
#       8     set_context,
#       9 )
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/data_context/__init__.py:1
# ----> 1 from great_expectations.data_context.data_context.abstract_data_context import (
#       2     AbstractDataContext,
#       3 )
#       4 from great_expectations.data_context.data_context.cloud_data_context import (
#       5     CloudDataContext,
#       6 )
#       7 from great_expectations.data_context.data_context.context_factory import (
#       8     get_context,
#       9     project_manager,
#      10     set_context,
#      11 )
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/data_context/abstract_data_context.py:43
#      41 from great_expectations.analytics.events import DataContextInitializedEvent
#      42 from great_expectations.compatibility.typing_extensions import override
# ---> 43 from great_expectations.core import ExpectationSuite
#      44 from great_expectations.core.batch import (
#      45     Batch,
#      46     BatchRequestBase,
#      47     IDDict,
#      48     get_batch_request_from_acceptable_arguments,
#      49 )
#      50 from great_expectations.core.config_peer import ConfigPeer
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/core/__init__.py:21
#      19 from .result_format import ResultFormat
#      20 from .run_identifier import RunIdentifier, RunIdentifierSchema
# ---> 21 from .validation_definition import ValidationDefinition
#      23 __all__ = [
#      24     "Domain",
#      25     "ExpectationSuite",
#    (...)
#      38     "get_metric_kwargs_id",
#      39 ]
#      41 logger = logging.getLogger(__name__)
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/core/validation_definition.py:44
#      35 from great_expectations.exceptions import (
#      36     ValidationDefinitionNotAddedError,
#      37     ValidationDefinitionNotFreshError,
#      38 )
#      39 from great_expectations.exceptions.exceptions import (
#      40     InvalidKeyError,
#      41     StoreBackendError,
#      42     ValidationDefinitionNotFoundError,
#      43 )
# ---> 44 from great_expectations.validator.v1_validator import Validator
#      46 if TYPE_CHECKING:
#      47     from great_expectations.core.expectation_validation_result import (
#      48         ExpectationSuiteValidationResult,
#      49     )
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/validator/v1_validator.py:18
#      16 from great_expectations.data_context.data_context.context_factory import project_manager
#      17 from great_expectations.util import convert_to_json_serializable  # noqa: TID251 # FIXME CoP
# ---> 18 from great_expectations.validator.validator import Validator as OldValidator
#      19 from great_expectations.validator.validator import calc_validation_statistics
#      21 if TYPE_CHECKING:
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/validator/validator.py:47
#      42 from great_expectations.data_context.types.base import CheckpointValidationDefinition
#      43 from great_expectations.exceptions import (
#      44     GreatExpectationsError,
#      45     InvalidExpectationConfigurationError,
#      46 )
# ---> 47 from great_expectations.execution_engine.pandas_batch_data import PandasBatchData
#      48 from great_expectations.expectations.expectation_configuration import (
#      49     ExpectationConfiguration,
#      50 )
#      51 from great_expectations.expectations.registry import (
#      52     get_expectation_impl,
#      53     list_registered_expectation_implementations,
#      54 )
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/execution_engine/__init__.py:1
# ----> 1 from .execution_engine import ExecutionEngine
#       2 from .pandas_execution_engine import PandasExecutionEngine
#       3 from .sparkdf_execution_engine import SparkDFExecutionEngine
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/execution_engine/execution_engine.py:24
#      22 from great_expectations.core.batch_manager import BatchManager
#      23 from great_expectations.core.metric_domain_types import MetricDomainTypes
# ---> 24 from great_expectations.expectations.registry import get_metric_provider
#      25 from great_expectations.expectations.row_conditions import (
#      26     RowCondition,
#      27     RowConditionParserType,
#      28 )
#      29 from great_expectations.types import DictDot
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/expectations/__init__.py:3
#       1 from great_expectations.expectations.expectation import Expectation
# ----> 3 from .core import (
#       4     ExpectColumnDistinctValuesToBeInSet,
#       5     ExpectColumnDistinctValuesToContainSet,
#       6     ExpectColumnDistinctValuesToEqualSet,
#       7     ExpectColumnKLDivergenceToBeLessThan,
#       8     ExpectColumnMaxToBeBetween,
#       9     ExpectColumnMeanToBeBetween,
#      10     ExpectColumnMedianToBeBetween,
#      11     ExpectColumnMinToBeBetween,
#      12     ExpectColumnMostCommonValueToBeInSet,
#      13     ExpectColumnPairValuesAToBeGreaterThanB,
#      14     ExpectColumnPairValuesToBeEqual,
#      15     ExpectColumnPairValuesToBeInSet,
#      16     ExpectColumnProportionOfUniqueValuesToBeBetween,
#      17     ExpectColumnQuantileValuesToBeBetween,
#      18     ExpectColumnStdevToBeBetween,
#      19     ExpectColumnSumToBeBetween,
#      20     ExpectColumnToExist,
#      21     ExpectColumnUniqueValueCountToBeBetween,
#      22     ExpectColumnValueLengthsToBeBetween,
#      23     ExpectColumnValueLengthsToEqual,
#      24     ExpectColumnValuesToBeBetween,
#      25     ExpectColumnValuesToBeDateutilParseable,
#      26     ExpectColumnValuesToBeDecreasing,
#      27     ExpectColumnValuesToBeIncreasing,
#      28     ExpectColumnValuesToBeInSet,
#      29     ExpectColumnValuesToBeInTypeList,
#      30     ExpectColumnValuesToBeJsonParseable,
#      31     ExpectColumnValuesToBeNull,
#      32     ExpectColumnValuesToBeOfType,
#      33     ExpectColumnValuesToBeUnique,
#      34     ExpectColumnValuesToMatchJsonSchema,
#      35     ExpectColumnValuesToMatchLikePattern,
#      36     ExpectColumnValuesToMatchLikePatternList,
#      37     ExpectColumnValuesToMatchRegex,
#      38     ExpectColumnValuesToMatchRegexList,
#      39     ExpectColumnValuesToMatchStrftimeFormat,
#      40     ExpectColumnValuesToNotBeInSet,
#      41     ExpectColumnValuesToNotBeNull,
#      42     ExpectColumnValuesToNotMatchLikePattern,
#      43     ExpectColumnValuesToNotMatchLikePatternList,
#      44     ExpectColumnValuesToNotMatchRegex,
#      45     ExpectColumnValuesToNotMatchRegexList,
#      46     ExpectColumnValueZScoresToBeLessThan,
#      47     ExpectCompoundColumnsToBeUnique,
#      48     ExpectMulticolumnSumToEqual,
#      49     ExpectMulticolumnValuesToBeUnique,
#      50     ExpectQueryResultsToMatchComparison,
#      51     ExpectSelectColumnValuesToBeUniqueWithinRecord,
#      52     ExpectTableColumnCountToBeBetween,
#      53     ExpectTableColumnCountToEqual,
#      54     ExpectTableColumnsToMatchOrderedList,
#      55     ExpectTableColumnsToMatchSet,
#      56     ExpectTableRowCountToBeBetween,
#      57     ExpectTableRowCountToEqual,
#      58     ExpectTableRowCountToEqualOtherTable,
#      59     UnexpectedRowsExpectation,
#      60 )
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/expectations/core/__init__.py:10
#       4 from .expect_column_distinct_values_to_contain_set import (
#       5     ExpectColumnDistinctValuesToContainSet,
#       6 )
#       7 from .expect_column_distinct_values_to_equal_set import (
#       8     ExpectColumnDistinctValuesToEqualSet,
#       9 )
# ---> 10 from .expect_column_kl_divergence_to_be_less_than import (
#      11     ExpectColumnKLDivergenceToBeLessThan,
#      12 )
#      13 from .expect_column_max_to_be_between import ExpectColumnMaxToBeBetween
#      14 from .expect_column_mean_to_be_between import ExpectColumnMeanToBeBetween
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/expectations/core/expect_column_kl_divergence_to_be_less_than.py:9
#       7 import numpy as np
#       8 import pandas as pd
# ----> 9 from scipy import stats
#      11 from great_expectations.compatibility import pydantic
#      12 from great_expectations.core.types import Comparable  # noqa: TC001 # FIXME CoP
#
# File ~/.local/lib/python3.10/site-packages/scipy/__init__.py:134, in __getattr__(name)
#     132 def __getattr__(name):
#     133     if name in submodules:
# --> 134         return _importlib.import_module(f'scipy.{name}')
#     135     else:
#     136         try:
#
# File /usr/local/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/.local/lib/python3.10/site-packages/scipy/stats/__init__.py:624
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     619
#     620 """  # noqa: E501
#     622 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     623                                DegenerateDataWarning, FitError)
# --> 624 from ._stats_py import *
#     625 from ._variation import variation
#     626 from .distributions import *
#
# File ~/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:38
#      35 import numpy as np
#      36 from numpy import array, asarray, ma
# ---> 38 from scipy import sparse
#      39 from scipy.spatial import distance_matrix
#      41 from scipy.optimize import milp, LinearConstraint
#
# File ~/.local/lib/python3.10/site-packages/scipy/__init__.py:134, in __getattr__(name)
#     132 def __getattr__(name):
#     133     if name in submodules:
# --> 134         return _importlib.import_module(f'scipy.{name}')
#     135     else:
#     136         try:
#
# File /usr/local/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/.local/lib/python3.10/site-packages/scipy/sparse/__init__.py:300
#     294 # Original code by Travis Oliphant.
#     295 # Modified and extended by Ed Schofield, Robert Cimrman,
#     296 # Nathan Bell, and Jake Vanderplas.
#     298 import warnings as _warnings
# --> 300 from ._base import *
#     301 from ._csr import *
#     302 from ._csc import *
#
# File ~/.local/lib/python3.10/site-packages/scipy/sparse/_base.py:5
#       1 """Base class for sparse matrices"""
#       3 import numpy as np
# ----> 5 from ._sputils import (asmatrix, check_reshape_kwargs, check_shape,
#       6                        get_sum_dtype, isdense, isscalarlike,
#       7                        matrix, validateaxis, getdtype)
#       9 from ._matrix import spmatrix
#      11 __all__ = ['isspmatrix', 'issparse', 'sparray',
#      12            'SparseWarning', 'SparseEfficiencyWarning']
#
# File ~/.local/lib/python3.10/site-packages/scipy/sparse/_sputils.py:10
#       8 from math import prod
#       9 import scipy.sparse as sp
# ---> 10 from scipy._lib._util import np_long, np_ulong
#      13 __all__ = ['upcast', 'getdtype', 'getdata', 'isscalarlike', 'isintlike',
#      14            'isshape', 'issequence', 'isdense', 'ismatrix', 'get_sum_dtype',
#      15            'broadcast_shapes']
#      17 supported_dtypes = [np.bool_, np.byte, np.ubyte, np.short, np.ushort, np.intc,
#      18                     np.uintc, np_long, np_ulong, np.longlong, np.ulonglong,
#      19                     np.float32, np.float64, np.longdouble,
#      20                     np.complex64, np.complex128, np.clongdouble]
#
# File ~/.local/lib/python3.10/site-packages/scipy/_lib/_util.py:13
#      10 from typing import TypeAlias, TypeVar
#      12 import numpy as np
# ---> 13 from scipy._lib._array_api import array_namespace, is_numpy, xp_size
#      14 from scipy._lib._docscrape import FunctionDoc, Parameter
#      17 AxisError: type[Exception]
#
# File ~/.local/lib/python3.10/site-packages/scipy/_lib/_array_api.py:18
#      15 import numpy.typing as npt
#      17 from scipy._lib import array_api_compat
# ---> 18 from scipy._lib.array_api_compat import (
#      19     is_array_api_obj,
#      20     size as xp_size,
#      21     numpy as np_compat,
#      22     device as xp_device,
#      23     is_numpy_namespace as is_numpy,
#      24     is_cupy_namespace as is_cupy,
#      25     is_torch_namespace as is_torch,
#      26     is_jax_namespace as is_jax,
#      27     is_array_api_strict_namespace as is_array_api_strict
#      28 )
#      30 __all__ = [
#      31     '_asarray', 'array_namespace', 'assert_almost_equal', 'assert_array_almost_equal',
#      32     'get_xp_devices',
#    (...)
#      38     'xp_take_along_axis', 'xp_unsupported_param_msg', 'xp_vector_norm',
#      39 ]
#      42 # To enable array API and strict array-like input validation
#
# File ~/.local/lib/python3.10/site-packages/scipy/_lib/array_api_compat/numpy/__init__.py:1
# ----> 1 from numpy import * # noqa: F403
#       3 # from numpy import * doesn't overwrite these builtin names
#       4 from numpy import abs, max, min, round # noqa: F401
#
# File ~/.local/lib/python3.10/site-packages/numpy/__init__.py:379, in __getattr__(attr)
#     377 def _mac_os_check():
#     378     """
# --> 379     Quick Sanity check for Mac OS look for accelerate build bugs.
#     380     Testing numpy polyfit calls init_dgelsd(LAPACK)
#     381     """
#     382     try:
#     383         c = array([3., 2., 1.])
#
# ModuleNotFoundError: No module named 'numpy.strings'
